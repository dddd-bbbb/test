# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel(r"C:\Users\a\OneDrive\ドキュメント\kabu_doc\売買.xlsx", sheet_name="資金の遷移", index_col="日付")
data
# Out:
#                    残高      前日比       年初比         余力    株式購入金額      現金比率  \
# 日付
# 2019-01-01   384517.0      NaN       NaN        NaN       NaN       NaN
# 2019-11-21   361469.0 -23048.0  -23048.0        NaN       NaN       NaN
# 2019-11-22   360069.0  -1400.0   -1400.0        NaN       NaN       NaN
# 2019-11-27   366369.0   6300.0    6300.0        NaN       NaN       NaN
# 2019-11-28   367589.0   1220.0    1220.0        NaN       NaN       NaN
# ...               ...      ...       ...        ...       ...       ...
# 2020-09-11  1787288.0    900.0  173269.0  1394688.0  392600.0  0.780338
# 2020-09-14  1790488.0   3200.0  176469.0  1384588.0  405900.0  0.773302
# 2020-09-15  1790888.0    400.0  176869.0  1409288.0  381600.0  0.786921
# 2020-09-16  1793588.0   2700.0  179569.0  1377088.0  416500.0  0.767784
# 2020-09-17  1808598.0  15010.0  194579.0  1446598.0  362000.0  0.806539
#
#                  株比率      前月比%  TOPIX200乖離  TOPIX25乖離  ...    FG   銘柄数  \
# 日付                                                     ...
# 2019-01-01       NaN       NaN         NaN        NaN  ...   NaN   NaN
# 2019-11-21       NaN       NaN         NaN        NaN  ...   NaN   NaN
# 2019-11-22       NaN       NaN         NaN        NaN  ...   NaN   NaN
# 2019-11-27       NaN       NaN         NaN        NaN  ...   NaN   NaN
# 2019-11-28       NaN       NaN         NaN        NaN  ...   NaN   NaN
# ...              ...       ...         ...        ...  ...   ...   ...
# 2020-09-11  0.219662  0.008788      0.0633     0.0134  ...  59.0  14.0
# 2020-09-14  0.226698  0.010594      0.0464     0.0215  ...  58.0  15.0
# 2020-09-15  0.213079  0.010820      0.0401     0.0138  ...  59.0  13.0
# 2020-09-16  0.232216  0.012344      0.0425     0.0150  ...  59.0  16.0
# 2020-09-17  0.193461  0.020816      0.0389     0.0110  ...   NaN  16.0
#
#                                                  売買メモ  全体相場参照     全体相場メモ  \
# 日付
# 2019-01-01                                        NaN     NaN        NaN
# 2019-11-21                                        NaN     NaN        NaN
# 2019-11-22                                        NaN     NaN        NaN
# 2019-11-27                                        NaN     NaN        NaN
# 2019-11-28                                        NaN     NaN        NaN
# ...                                               ...     ...        ...
# 2020-09-11                                        NaN     NaN        NaN
# 2020-09-14                                 ぱどS100@223     NaN        NaN
# 2020-09-15      レッドS100@79全200a115 ウインテストS100@168全0a0     NaN        NaN
# 2020-09-16  フォーサイドB100@94  バナーズB100@109  価値開発B100@119     NaN  低位株じわ上げ大量
# 2020-09-17                                        NaN     NaN        NaN
#
#             ポジション詳細画像URL  追加資金  追加経過日数  年初からの経過  削減資金
# 日付
# 2019-01-01           NaN   NaN     NaN      NaN   NaN
# 2019-11-21           NaN   NaN     NaN      NaN   NaN
# 2019-11-22           NaN   NaN     NaN      NaN   NaN
# 2019-11-27           NaN   NaN     NaN      NaN   NaN
# 2019-11-28           NaN   NaN     NaN      NaN   NaN
# ...                  ...   ...     ...      ...   ...
# 2020-09-11           NaN   NaN     NaN      NaN   NaN
# 2020-09-14           NaN   NaN     NaN      NaN   NaN
# 2020-09-15           NaN   NaN     NaN      NaN   NaN
# 2020-09-16           NaN   NaN     NaN      NaN   NaN
# 2020-09-17           NaN   NaN     NaN      NaN   NaN
#
# [163 rows x 28 columns]

# %%
fig, ax1=plt.subplots() 
plt.plot(data["TOPIX"])
ax2 = ax1.twinx()
plt.plot(data["評価損益"], "red")

# %%
"1つのポジションのリスク最大許容値の範囲"
balance = float(data.tail(1)["残高"])
print(f"min {balance*0.05:.2f}")
print(f"max {balance*0.10:.2f}")
# Out:
# 1つのポジションのリスク90429.90
# 1つのポジションのリスク180859.80
