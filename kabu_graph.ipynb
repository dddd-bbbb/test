# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel(r"C:\Users\a\OneDrive\ドキュメント\kabu_doc\売買.xlsx", sheet_name="全体相場", index_col="日付")
data.describe()
# Out:
#              値上がり数        値下がり数  値上がり数/値上がり数        S高数        S安数    S高数/S安数  \
# count    66.000000    66.000000    66.000000  66.000000  66.000000  66.000000
# mean   1837.166667  1954.727273     1.472648  15.469697   2.742424   8.939417
# std     778.250179   783.874118     1.794905   5.706190   2.150568   6.524285
# min     421.000000   288.000000     0.119095   6.000000   1.000000   0.818182
# 25%    1238.500000  1403.500000     0.487916  10.250000   1.000000   3.600000
# 50%    1801.500000  1925.000000     0.932922  15.000000   2.000000   7.000000
# 75%    2377.000000  2513.500000     1.680405  19.000000   4.000000  12.875000
# max    3628.000000  3535.000000    12.597222  35.000000  12.000000  27.000000
#
#               新高値          新安値     新高値/新安値      日経PBR  ...       裁定売残  \
# count   66.000000    73.000000   66.000000  82.000000  ...  79.000000
# mean    98.696970    79.671233   21.116585   1.076463  ...   7.377797
# ...

# %%
fig, ax1=plt.subplots() 
plt.plot(data["日経"])
ax2 = ax1.twinx()
plt.plot(data["値上がり数/値上がり数"], "red")
